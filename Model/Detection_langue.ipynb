# %%
# !pip install fasttext-wheel
# !pip install numpy==1.26.4

# %%
! gdown --id 1HnGTJMw1MWd5rHnjnEmaybnahV-nf5FR
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1HnGTJMw1MWd5rHnjnEmaybnahV-nf5FR
# From (redirected): https://drive.google.com/uc?id=1HnGTJMw1MWd5rHnjnEmaybnahV-nf5FR&confirm=t&uuid=181d8587-cc2d-4918-b348-bfe05ef58bed
# To: /content/lid218e.bin
# 100% 1.18G/1.18G [00:15<00:00, 75.9MB/s]

# %%
import fasttext

model=fasttext.load_model("/content/lid218e.bin")

# %%
#Caractéristiques
dir(model)
# Out:
# ['__class__',
#  '__contains__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_labels',
#  '_words',
#  'f',
#  'get_analogies',
#  'get_dimension',
#  'get_input_matrix',
#  'get_input_vector',
#  'get_label_id',
#  'get_labels',
#  'get_line',
#  'get_meter',
#  'get_nearest_neighbors',
#  'get_output_matrix',
#  'get_sentence_vector',
#  'get_subword_id',
#  'get_subwords',
#  'get_word_id',
#  'get_word_vector',
#  'get_words',
#  'is_quantized',
#  'labels',
#  'predict',
#  'quantize',
#  'save_model',
#  'set_args',
#  'set_matrices',
#  'test',
#  'test_label',
#  'words']

# %%
#liste des langues reconnues
model.get_labels()
# Out:
# ['__label__srp_Cyrl',
#  '__label__swe_Latn',
#  '__label__dan_Latn',
#  '__label__ita_Latn',
#  '__label__spa_Latn',
#  '__label__pes_Arab',
#  '__label__slk_Latn',
#  '__label__hun_Latn',
#  '__label__bul_Cyrl',
#  '__label__cat_Latn',
#  '__label__tur_Latn',
#  '__label__ell_Grek',
#  '__label__eng_Latn',
#  '__label__nob_Latn',
#  '__label__fra_Latn',
#  '__label__rus_Cyrl',
#  '__label__hrv_Latn',
#  '__label__nld_Latn',
#  '__label__ind_Latn',
#  '__label__hye_Armn',
#  '__label__heb_Hebr',
#  '__label__ceb_Latn',
#  '__label__ron_Latn',
#  '__label__pol_Latn',
#  '__label__kor_Hang',
#  '__label__vie_Latn',
#  '__label__deu_Latn',
#  '__label__slv_Latn',
#  '__label__por_Latn',
#  '__label__ces_Latn',
#  '__label__ukr_Cyrl',
#  '__label__fin_Latn',
#  '__label__arb_Arab',
#  '__label__tgl_Latn',
#  '__label__afr_Latn',
#  '__label__est_Latn',
#  '__label__war_Latn',
#  '__label__zul_Latn',
#  '__label__lit_Latn',
#  '__label__ilo_Latn',
#  '__label__kat_Geor',
# ...

# %%
labels = model.get_labels()
print('\n'.join(labels))
# Out:
# __label__srp_Cyrl
# __label__swe_Latn
# __label__dan_Latn
# __label__ita_Latn
# __label__spa_Latn
# __label__pes_Arab
# __label__slk_Latn
# __label__hun_Latn
# __label__bul_Cyrl
# __label__cat_Latn
# __label__tur_Latn
# __label__ell_Grek
# __label__eng_Latn
# __label__nob_Latn
# __label__fra_Latn
# __label__rus_Cyrl
# __label__hrv_Latn
# __label__nld_Latn
# __label__ind_Latn
# __label__hye_Armn
# __label__heb_Hebr
# __label__ceb_Latn
# __label__ron_Latn
# __label__pol_Latn
# __label__kor_Hang
# __label__vie_Latn
# __label__deu_Latn
# __label__slv_Latn
# __label__por_Latn
# __label__ces_Latn
# __label__ukr_Cyrl
# __label__fin_Latn
# __label__arb_Arab
# __label__tgl_Latn
# __label__afr_Latn
# __label__est_Latn
# __label__war_Latn
# __label__zul_Latn
# __label__lit_Latn
# __label__ilo_Latn
# __label__kat_Geor
# __label__hin_Deva
# __label__mkd_Cyrl
# __label__swh_Latn
# __label__epo_Latn
# __label__sot_Latn
# __label__tsn_Latn
# __label__xho_Latn
# __label__lvs_Latn
# __label__als_Latn
# ...

# %%
#Texte en français
model.predict("J’espère que tu vas bien. Je voulais juste prendre un moment pour t’envoyer ce petit message afin de te dire que je pense à toi. Que cette journée t’apporte paix, bonheur et réussite dans tout ce que tu entreprends. N’oublie pas que tu es capable de grandes choses !")
# Out:
# (('__label__fra_Latn',), array([0.98013222]))

# %%
#Texte en Anglais

# %%
model.predict("I hope you are well. I just wanted to take a moment to send you this little message to let you know that I am thinking of you. May this day bring you peace, happiness, and success in all that you do. Remember that you are capable of great things!")
# Out:
# (('__label__eng_Latn',), array([0.99999154]))

# %%
# Texte en Swahili
model.predict("Natumai u mzima. Nilitaka tu kuchukua muda kukutumia ujumbe huu mdogo ili kukujulisha kuwa ninakufikiria. Siku hii ikuletee amani, furaha, na mafanikio katika yote unayofanya. Kumbuka kwamba una uwezo wa mambo makubwa!")
# Out:
# (('__label__swh_Latn',), array([1.00000823]))

# %%
#Texte en arabe
model.predict("أتمنى أن تكون بخير. أردتُ فقط أن أرسل لك هذه الرسالة القصيرة لأُخبرك أنني أفكر بك. عسى أن يحمل لك هذا اليوم السلام والسعادة والنجاح في كل ما تفعله. تذكر أنك قادر على تحقيق أشياء عظيمة!")
# Out:
# (('__label__arb_Arab',), array([1.00000858]))

# %%
# Texte à analyser
texte_français= """J’espère que tu vas bien. Je voulais juste prendre un moment pour t’envoyer ce petit message afin de te dire que je pense à toi. Que cette journée t’apporte paix, bonheur et réussite dans tout ce que tu entreprends. N’oublie pas que tu es capable de grandes choses !"""

texte_arabe=""" أتمنى أن تكون بخير. أردتُ فقط أن أرسل لك هذه الرسالة القصيرة لأُخبرك أنني أفكر بك. عسى أن يحمل لك هذا اليوم السلام والسعادة والنجاح في كل ما تفعله. تذكر أنك قادر على تحقيق أشياء عظيمة!"""

# %%
#Supprimer les sauts de ligne
texte_français = texte_français.replace("\n", " ")
texte_arabe = texte_arabe.replace("\n", " ")

# %%
label_to_lang = {
    '__label__srp_Cyrl': 'Serbe (cyrillique)',
    '__label__swe_Latn': 'Suédois',
    '__label__dan_Latn': 'Danois',
    '__label__ita_Latn': 'Italien',
    '__label__spa_Latn': 'Espagnol',
    '__label__pes_Arab': 'Persan (arabe)',
    '__label__slk_Latn': 'Slovaque',
    '__label__hun_Latn': 'Hongrois',
    '__label__bul_Cyrl': 'Bulgare',
    '__label__cat_Latn': 'Catalan',
    '__label__tur_Latn': 'Turc',
    '__label__ell_Grek': 'Grec',
    '__label__eng_Latn': 'Anglais',
    '__label__nob_Latn': 'Norvégien (Bokmål)',
    '__label__fra_Latn': 'Français',
    '__label__rus_Cyrl': 'Russe',
    '__label__hrv_Latn': 'Croate',
    '__label__nld_Latn': 'Néerlandais',
    '__label__ind_Latn': 'Indonésien',
    '__label__hye_Armn': 'Arménien',
    '__label__heb_Hebr': 'Hébreu',
    '__label__ceb_Latn': 'Cebuano',
    '__label__ron_Latn': 'Roumain',
    '__label__pol_Latn': 'Polonais',
    '__label__kor_Hang': 'Coréen',
    '__label__vie_Latn': 'Vietnamien',
    '__label__deu_Latn': 'Allemand',
    '__label__slv_Latn': 'Slovène',
    '__label__por_Latn': 'Portugais',
    '__label__ces_Latn': 'Tchèque',
    '__label__ukr_Cyrl': 'Ukrainien',
    '__label__fin_Latn': 'Finnois',
    '__label__arb_Arab': 'Arabe',
    '__label__tgl_Latn': 'Tagalog',
    '__label__afr_Latn': 'Afrikaans',
    '__label__est_Latn': 'Estonien',
    '__label__war_Latn': 'Waray',
    '__label__zul_Latn': 'Zoulou',
    '__label__lit_Latn': 'Lituanien',
    '__label__ilo_Latn': 'Ilocano',
    '__label__kat_Geor': 'Géorgien',
    '__label__hin_Deva': 'Hindi',
    '__label__mkd_Cyrl': 'Macédonien',
    '__label__swh_Latn': 'Swahili',
    '__label__epo_Latn': 'Espéranto',
    '__label__sot_Latn': 'Sotho du Sud',
    '__label__tsn_Latn': 'Tswana',
    '__label__xho_Latn': 'Xhosa',
    '__label__lvs_Latn': 'Letton',
    '__label__als_Latn': 'Albanais (Tosk)',
    '__label__tso_Latn': 'Tsonga',
    '__label__kaz_Cyrl': 'Kazakh',
    '__label__sna_Latn': 'Shona',
    '__label__amh_Ethi': 'Amharique',
    '__label__zsm_Latn': 'Malaisien',
    '__label__tha_Thai': 'Thaï',
    '__label__tah_Latn': 'Tahitien',
    '__label__nso_Latn': 'Sotho du Nord',
    '__label__ewe_Latn': 'Éwé',
    '__label__urd_Arab': 'Ourdou',
    '__label__isl_Latn': 'Islandais',
    '__label__lin_Latn': 'Lingala',
    '__label__bis_Latn': 'Bichelamar',
    '__label__twi_Latn': 'Twi',
    '__label__sin_Sinh': 'Singhalais',
    '__label__ben_Beng': 'Bengali',
    '__label__mya_Mymr': 'Birman',
    '__label__plt_Latn': 'Plateau Malagasy',
    '__label__pan_Guru': 'Pendjabi (Gurmukhi)',
    '__label__azj_Latn': 'Azéri (du Nord)',
    '__label__guj_Gujr': 'Gujarati',
    '__label__glg_Latn': 'Galicien',
    '__label__kir_Cyrl': 'Kirghiz',
    '__label__tel_Telu': 'Télougou',
    '__label__tpi_Latn': 'Tok Pisin',
    '__label__ibo_Latn': 'Igbo',
    '__label__tam_Taml': 'Tamoul',
    '__label__tat_Cyrl': 'Tatar',
    '__label__bem_Latn': 'Bemba',
    '__label__bel_Cyrl': 'Biélorusse',
    '__label__kin_Latn': 'Kinyarwanda',
    '__label__npi_Deva': 'Népalais (devanagari)',
    '__label__pap_Latn': 'Papiamento',
    '__label__mar_Deva': 'Marathi',
    '__label__smo_Latn': 'Samoan',
    '__label__run_Latn': 'Kirundi',
    '__label__che_Cyrl': 'Tchétchène',
    '__label__fij_Latn': 'Fidjien',
    '__label__tir_Ethi': 'Tigrigna',
    '__label__ast_Latn': 'Asturien',
    '__label__kan_Knda': 'Kannada',
    '__label__mlt_Latn': 'Maltais',
    '__label__yor_Latn': 'Yoruba',
    '__label__eus_Latn': 'Basque',
    '__label__lua_Latn': 'Luba-Lulua',
    '__label__pag_Latn': 'Pangasinan',
    '__label__sag_Latn': 'Sango',
    '__label__oss_Cyrl': 'Ossète',
    '__label__khk_Cyrl': 'Mongol (Khalkha)',
    '__label__tum_Latn': 'Tumbuka',
    '__label__tgk_Cyrl': 'Tadjik',
    '__label__lug_Latn': 'Ganda',
    '__label__mal_Mlym': 'Malayalam',
    '__label__umb_Latn': 'Umbundu',
    '__label__hat_Latn': 'Haïtien',
    '__label__kon_Latn': 'Kikongo',
    '__label__azb_Arab': 'Azéri du Sud',
    '__label__hau_Latn': 'Haoussa',
    '__label__mos_Latn': 'Mossi',
    '__label__kal_Latn': 'Groenlandais',
    '__label__nno_Latn': 'Norvégien (Nynorsk)',
    '__label__lus_Latn': 'Lushai (Mizo)',
    '__label__oci_Latn': 'Occitan',
    '__label__bos_Latn': 'Bosniaque',
    '__label__gaz_Latn': 'Oromo (Ouest central)',
    '__label__bak_Cyrl': 'Bachkir',
    '__label__chv_Cyrl': 'Tchouvache',
    '__label__cym_Latn': 'Gallois',
    '__label__tuk_Latn': 'Turkmène',
    '__label__luo_Latn': 'Luo',
    '__label__ayr_Latn': 'Aymara (Sud)',
    '__label__ssw_Latn': 'Swati',
    '__label__quy_Latn': 'Quechua (Ayacucho)',
    '__label__uzn_Latn': 'Ouzbek (du Nord)',
    '__label__kik_Latn': 'Kikuyu',
    '__label__kmb_Latn': 'Kimbundu',
    '__label__jav_Latn': 'Javanais',
    '__label__ltz_Latn': 'Luxembourgeois',
    '__label__asm_Beng': 'Assamais',
    '__label__ton_Latn': 'Tongien',
    '__label__nya_Latn': 'Chichewa',
    '__label__kam_Latn': 'Kamba',
    '__label__ckb_Arab': 'Kurde central (Sorani)',
    '__label__min_Latn': 'Minangkabau',
    '__label__bod_Tibt': 'Tibétain',
    '__label__lmo_Latn': 'Lombard',
    '__label__gle_Latn': 'Irlandais',
    '__label__sun_Latn': 'Soundanais',
    '__label__xmf_Geor': 'Mingrélien',
    '__label__cjk_Latn': 'Chokwe',
    '__label__nia_Latn': 'Nias',
    '__label__kbp_Latn': 'Kabiyè',
    '__label__ory_Orya': 'Oriya',
    '__label__fon_Latn': 'Fon',
    '__label__kmr_Latn': 'Kurde (Kurmanji)',
    '__label__khm_Khmr': 'Khmer',
    '__label__ydd_Hebr': 'Yiddish',
    '__label__abk_Cyrl': 'Abkhaze',
    '__label__san_Deva': 'Sanskrit',
    '__label__uig_Arab': 'Ouïghour',
    '__label__lim_Latn': 'Limbourgeois',
    '__label__scn_Latn': 'Sicilien',
    '__label__mai_Deva': 'Maithili',
    '__label__snd_Arab': 'Sindhi',
    '__label__wes_Latn': 'Cameroon Pidgin',
    '__label__pcm_Latn': 'Nigerian Pidgin',
    '__label__arn_Latn': 'Mapudungun',
    '__label__vec_Latn': 'Vénitien',
    '__label__nav_Latn': 'Navajo',
    '__label__gom_Deva': 'Konkani (Goa)',
    '__label__gla_Latn': 'Gaélique écossais',
    '__label__yue_Hant': 'Cantonais (trad.)',
    '__label__dyu_Latn': 'Dioula',
    '__label__kac_Latn': 'Kachin',
    '__label__roh_Latn': 'Romanche',
    '__label__udm_Cyrl': 'Oudmourte',
    '__label__lao_Laoo': 'Laotien',
    '__label__diq_Latn': 'Zazaki',
    '__label__som_Latn': 'Somali',
    '__label__kab_Latn': 'Kabyle',
    '__label__bjn_Latn': 'Banjarese',
    '__label__bxr_Cyrl': 'Bouriate',
    '__label__knc_Arab': 'Kanouri (arabe)',
    '__label__szl_Latn': 'Silésien',
    '__label__kea_Latn': 'Capverdien',
    '__label__ban_Latn': 'Balinais',
    '__label__crh_Latn': 'Tatar de Crimée',
    '__label__knc_Latn': 'Kanouri (latin)',
    '__label__bug_Latn': 'Bugis',
    '__label__fur_Latn': 'Frioulan',
    '__label__ace_Latn': 'Acehnais',
    '__label__fuv_Latn': 'Fulfulde nigérian',
    '__label__prs_Arab': 'Dari',
    '__label__mri_Latn': 'Maori',
    '__label__dik_Latn': 'Dinka',
    '__label__taq_Latn': 'Tamahaq (latin)',
    '__label__kas_Arab': 'Cachemiri (arabe)',
    '__label__pbt_Arab': 'Pachto',
    '__label__tzm_Tfng': 'Tamazight (Tifinagh)',
    '__label__bam_Latn': 'Bambara',
    '__label__mag_Deva': 'Magahi',
    '__label__hne_Deva': 'Chhattisgarhi',
    '__label__kas_Deva': 'Cachemiri (devanagari)',
    '__label__nus_Latn': 'Nuer',
    '__label__krc_Cyrl': 'Karatchaï-Balkar',
    '__label__bho_Deva': 'Bhojpuri',
    '__label__mni_Beng': 'Meitei',
    '__label__ltg_Latn': 'Latgalien',
    '__label__alt_Cyrl': 'Altaï',
    '__label__dzo_Tibt': 'Dzongkha',
    '__label__lij_Latn': 'Ligurien',
    '__label__wol_Latn': 'Wolof',
    '__label__sat_Olck': 'Santali',
    '__label__taq_Tfng': 'Tamahaq (Tifinagh)',
    '__label__jpn_Jpan': 'Japonais',
    '__label__shn_Mymr': 'Shan',
    '__label__bjn_Arab': 'Banjarese (arabe)',
    '__label__ace_Arab': 'Acehnais (arabe)',
    '__label__grn_Latn': 'Guarani',
    '__label__fao_Latn': 'Féroïen',
    '__label__zho_Hans': 'Chinois (simpl.)',
    '__label__zho_Hant': 'Chinois (trad.)',
    '__label__awa_Deva': 'Awadhi',
    '__label__aka_Latn': 'Akan',
    '__label__arb_Latn': 'Arabe (latinisé)',
    '__label__ewo_Latn': 'Ewondo',
    '__label__srd_Latn': 'Sarde',
    '__label__ady_Cyrl': 'Adyghé'
}

# %%
# Prédiction
label, prob = model.predict(texte_français)
code = label[0]
langue = label_to_lang.get(code, f"(langue inconnue : {code})")

print(f"Langue détectée : {langue} (confiance : {prob[0]:.4f})")
# Out:
# Langue détectée : Français (confiance : 0.9801)

# %%
# Prédiction
label, prob = model.predict(texte_arabe)
code = label[0]
langue = label_to_lang.get(code, f"(langue inconnue : {code})")

print(f"Langue détectée : {langue} (confiance : {prob[0]:.4f})")
# Out:
# Langue détectée : Arabe (confiance : 1.0000)
